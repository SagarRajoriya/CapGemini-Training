# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarRajoriya/CapGemini-Training/blob/main/RandomForestClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer,fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics import accuracy_score, r2_score, confusion_matrix, recall_score, precision_score, f1_score,mean_absolute_error,mean_squared_error

# %%
data=load_breast_cancer()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['cancer']=data.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
X=df.drop('cancer',axis=1)
y=df['cancer']
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model=RandomForestClassifier(n_estimators=150,max_depth=5)
model.fit(Xtrain,ytrain)
ypred=model.predict(Xtest)

# %%
model.score(Xtest,ytest)
# Out:
# 0.9707602339181286

# %%
model.score(Xtrain,ytrain)
# Out:
# 0.992462311557789

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[ 59,   4],
#        [  1, 107]])

# %%
confusion_matrix(ytrain,model.predict(Xtrain))
# Out:
# array([[146,   3],
#        [  0, 249]])

# %%
recall_score(ytest,ypred)
# Out:
# 0.9907407407407407

# %%
recall_score(ytrain,model.predict(Xtrain))
# Out:
# 1.0

# %%
f1_score(ytest,ypred)
# Out:
# 0.9771689497716894

# %%
f1_score(ytrain,model.predict(Xtrain))
# Out:
# 0.9940119760479041
