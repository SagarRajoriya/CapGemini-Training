# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarRajoriya/CapGemini-Training/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import datasets

# %%
dir(datasets)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_arff_parser',
#  '_base',
#  '_california_housing',
#  '_covtype',
#  '_kddcup99',
#  '_lfw',
#  '_olivetti_faces',
#  '_openml',
#  '_rcv1',
#  '_samples_generator',
#  '_species_distributions',
#  '_svmlight_format_fast',
#  '_svmlight_format_io',
#  '_twenty_newsgroups',
#  'clear_data_home',
#  'descr',
#  'dump_svmlight_file',
#  'fetch_20newsgroups',
#  'fetch_20newsgroups_vectorized',
#  'fetch_california_housing',
#  'fetch_covtype',
#  'fetch_file',
#  'fetch_kddcup99',
#  'fetch_lfw_pairs',
#  'fetch_lfw_people',
#  'fetch_olivetti_faces',
#  'fetch_openml',
#  'fetch_rcv1',
#  'fetch_species_distributions',
#  'get_data_home',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_sample_image',
#  'load_sample_images',
# ...

# %%
from sklearn.datasets import fetch_california_housing
#Object Creation
data = fetch_california_housing()
data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
#Creating a data frame
df = pd.DataFrame(data.data, columns=data.feature_names)
df['price'] = data.target  #Output column to store target values
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %%
X = df.drop('price',axis = 1) #Storeing input in output
Y = df['price']

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
Y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: price, Length: 20640, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test) #Y_pred is output , X_test is input
Y_pred
# Out:
# array([0.71656214, 1.76028165, 2.74676995, ..., 2.09517861, 1.58583885,
#        1.84290237])

# %%
model.score(X_train,Y_train)
# Out:
# 0.5906063380271864

# %%
model.score(X_test,Y_test)
# Out:
# 0.5993458597258202

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
r2 = r2_score(Y_test,Y_pred)
r2
# Out:
# 0.5993458597258202

# %%
X_test.shape
# Out:
# (6192, 8)

# %%
N= X_test.shape[0]
P = X_test.shape[1]
adjr2 = 1-((1-r2)*(N-1)/(N-P-1))
adjr2
# Out:
# 0.5988274652373529

# %%
mean_squared_error(Y_test,Y_pred)
# Out:
# 0.5258746284715426

# %%
mean_absolute_error(Y_test,Y_pred)
# Out:
# 0.5247841308303383

# %% [markdown]
# Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
LE = LabelEncoder()
OHE = OneHotEncoder(sparse_output = False)
OE = OrdinalEncoder()

# %%
data = pd.read_csv('https://github.com/Jeevita-R/ML_datasets/raw/refs/heads/main/House_price_prediction.csv')
data
# Out:
#        Unnamed: 0      Suburb  Rooms Type Method        SellerG  \
# 0               1  Abbotsford      2    h      S         Biggin
# 1               2  Abbotsford      2    h      S         Biggin
# 2               4  Abbotsford      3    h     SP         Biggin
# 3               5  Abbotsford      3    h     PI         Biggin
# 4               6  Abbotsford      4    h     VB         Nelson
# ...           ...         ...    ...  ...    ...            ...
# 27239       34852  Yarraville      4    h     PI            Jas
# 27240       34853  Yarraville      2    h     SP        Sweeney
# 27241       34854  Yarraville      2    t      S            Jas
# 27242       34855  Yarraville      3    h     SP  hockingstuart
# 27243       34856  Yarraville      2    h     PI             RW
#
#                   Regionname  Propertycount  Distance  \
# 0      Northern Metropolitan         4019.0       2.5
# 1      Northern Metropolitan         4019.0       2.5
# ...

# %%
df = pd.DataFrame(data)

# %%
df['Method_Encoded'] = LE.fit_transform(df['Method'])
df
# Out:
#        Unnamed: 0      Suburb  Rooms Type Method        SellerG  \
# 0               1  Abbotsford      2    h      S         Biggin
# 1               2  Abbotsford      2    h      S         Biggin
# 2               4  Abbotsford      3    h     SP         Biggin
# 3               5  Abbotsford      3    h     PI         Biggin
# 4               6  Abbotsford      4    h     VB         Nelson
# ...           ...         ...    ...  ...    ...            ...
# 27239       34852  Yarraville      4    h     PI            Jas
# 27240       34853  Yarraville      2    h     SP        Sweeney
# 27241       34854  Yarraville      2    t      S            Jas
# 27242       34855  Yarraville      3    h     SP  hockingstuart
# 27243       34856  Yarraville      2    h     PI             RW
#
#                   Regionname  Propertycount  Distance  \
# 0      Northern Metropolitan         4019.0       2.5
# 1      Northern Metropolitan         4019.0       2.5
# ...

# %%
df['Type_Encoded'] = LE.fit_transform(df['Type'])
df
# Out:
#        Unnamed: 0      Suburb  Rooms Type Method        SellerG  \
# 0               1  Abbotsford      2    h      S         Biggin
# 1               2  Abbotsford      2    h      S         Biggin
# 2               4  Abbotsford      3    h     SP         Biggin
# 3               5  Abbotsford      3    h     PI         Biggin
# 4               6  Abbotsford      4    h     VB         Nelson
# ...           ...         ...    ...  ...    ...            ...
# 27239       34852  Yarraville      4    h     PI            Jas
# 27240       34853  Yarraville      2    h     SP        Sweeney
# 27241       34854  Yarraville      2    t      S            Jas
# 27242       34855  Yarraville      3    h     SP  hockingstuart
# 27243       34856  Yarraville      2    h     PI             RW
#
#                   Regionname  Propertycount  Distance  \
# 0      Northern Metropolitan         4019.0       2.5
# 1      Northern Metropolitan         4019.0       2.5
# ...

# %%
pd.get_dummies(data,columns = ['Suburb','SellerG','Regionname','CouncilArea'] ,dtype = int)
# Out:
#        Unnamed: 0  Rooms Type Method  Propertycount  Distance  Bedroom2  \
# 0               1      2    h      S         4019.0       2.5       2.0
# 1               2      2    h      S         4019.0       2.5       2.0
# 2               4      3    h     SP         4019.0       2.5       3.0
# 3               5      3    h     PI         4019.0       2.5       3.0
# 4               6      4    h     VB         4019.0       2.5       3.0
# ...           ...    ...  ...    ...            ...       ...       ...
# 27239       34852      4    h     PI         6543.0       6.3       4.0
# 27240       34853      2    h     SP         6543.0       6.3       2.0
# 27241       34854      2    t      S         6543.0       6.3       2.0
# 27242       34855      3    h     SP         6543.0       6.3       0.0
# 27243       34856      2    h     PI         6543.0       6.3       2.0
#
#        Bathroom  Car    Landsize  ...  CouncilArea_Moorabool Shire Council  \
# ...

# %%
data['type_label'] = LE.fit_transform(data['Type'])

# %%
data = data.drop(columns=['Suburb','SellerG','Regionname','CouncilArea','Type','Method'])

# %%
X = data.drop(columns=['Price'])
y = data['Price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.4,random_state= 42)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.4047347584374803

# %%
model.score(X_test,y_test)
# Out:
# 0.4159041523749979

# %%
y_pred = model.predict(X_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 331855.3302985974

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 238144595792.60608

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.4159041523749979

# %%
N = X_test.shape[0]
P = X_test.shape[1]
adjr2 = (1-r2)*(N-1)/(N-P-1)
adjr2
# Out:
# 0.5846323552465921
